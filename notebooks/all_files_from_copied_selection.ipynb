# %%
from  bs4 import BeautifulSoup

def extract_links(html, file_type="pdf"):
    # Extract all links from a copied element of the page
    soup = BeautifulSoup(html, 'html.parser')
    return [x.get('href') for x in soup.find_all('a', href=True) if x.get('href') and x.get('href'
                                                                                            ).endswith(file_type)]
        
links = extract_links(example)
for x in links:
    print(x)
# Out:
# https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria/14-laukiz-aldizkaria.pdf
# https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria/13-laukiz-aldizkaria.pdf
# https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria/12-laukiz-aldizkaria.pdf
# https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria/11-laukiz-aldizkaria.pdf
# https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria/10-laukiz-aldizkaria-eu.pdf
# https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria/09-laukiz-aldizkaria.pdf
# https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria/08-laukiz-aldizkaria.pdf
# https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria/07-laukiz-aldizkaria.pdf
# https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria/06-laukiz-aldizkaria-eu.pdf
# https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria/05-laukiz-aldizkaria-eu.pdf
# ...

# %%
#Copied element from the webpage
example = """

<div class="template-wrapper">
                        <div class="container">
                           <span id="DeltaPlaceHolderMain">
                              
                              
                              
	<!--<div id="LeftMenu">
      <div id="rotativeImg">
      <img src="/Style Library/Images/banners/banner_01.jpg" alt="" />
      </div>
      <div id="ctl00_PlaceHolderMain_MiCityMenu1">

</div>
      
      <h2 class="SiteTitle">Argitalpenak</h2>
          Current Navigation 
         <div id="ctl00_PlaceHolderMain_ProceduresCategoriesMenu1">
	<div class="AspNet-Menu-Vertical"><ul class="AspNet-Menu"><li class="AspNet-Menu-Leaf"><a href="/eu-ES/Izapideak/Orriak/lista-procedimientos.aspx?mode=category&category=Gizarte ekintza" class="AspNet-Menu-Link">Gizarte ekintza</a></li><li class="AspNet-Menu-Leaf"><a href="/eu-ES/Izapideak/Orriak/lista-procedimientos.aspx?mode=category&category=Enplegua" class="AspNet-Menu-Link">Enplegua</a></li><li class="AspNet-Menu-Leaf"><a href="/eu-ES/Izapideak/Orriak/lista-procedimientos.aspx?mode=category&category=Zerga-kudeaketa" class="AspNet-Menu-Link">Zerga-kudeaketa</a></li><li class="AspNet-Menu-Leaf"><a href="/eu-ES/Izapideak/Orriak/lista-procedimientos.aspx?mode=category&category=Beste batzuk" class="AspNet-Menu-Link">Beste batzuk</a></li><li class="AspNet-Menu-Leaf"><a href="/eu-ES/Izapideak/Orriak/lista-procedimientos.aspx?mode=category&category=Errolda" class="AspNet-Menu-Link">Errolda</a></li><li class="AspNet-Menu-Leaf"><a href="/eu-ES/Izapideak/Orriak/lista-procedimientos.aspx?mode=category&category=Hiriko harremanak" class="AspNet-Menu-Link">Hiriko harremanak</a></li><li class="AspNet-Menu-Leaf"><a href="/eu-ES/Izapideak/Orriak/lista-procedimientos.aspx?mode=category&category=Zerbitzuak" class="AspNet-Menu-Link">Zerbitzuak</a></li><li class="AspNet-Menu-Leaf"><a href="/eu-ES/Izapideak/Orriak/lista-procedimientos.aspx?mode=category&category=Hirigintza eta Lanak" class="AspNet-Menu-Link">Hirigintza eta Lanak</a></li><li class="AspNet-Menu-Leaf"><a href="/eu-ES/Izapideak/Orriak/lista-procedimientos.aspx?mode=category&category=Hautaketa-prozesuak" class="AspNet-Menu-Link">Hautaketa-prozesuak</a></li></ul></div>
</div>
      </div>-->
<div class="layout-wrapper">
	<div id="MainContent" class="row contenidoLayout">
		<div id="BreadCrumbZone" class="breadcrumb col-12">
			<ul><li><a href="https://www.laukiz.eus/eu-ES">Laukiz</a></li><li><a href="/eu-ES/INFO/Orriak/default.aspx">INFO</a></li><li>Argitalpenak</li></ul>
		</div>
		<!--SITE TITLE-->
		<h2 class="title sr-only">
			Argitalpenak
		</h2>
		<div class="CenterZone box col-md-12 col-xl-9 col-lg-8">
			<div id="ProcedureLeftZone_auto" class="AspNet-WebPartZone-Vertical">

			<div>
				<div class="ms-WPHeader">
					<h3 class="ms-standardheader ms-WPTitle">
						Laukiz Aldizkaria
					</h3>
				</div><div class="ms-WPBody">
					<table cellspacing="0" cellpadding="0" class="cbq-layout-main"><tbody><tr><td valign="top"><ul><li><div class="CSPJobVacancyContainer"><table class="linkitem item"><tbody><tr><td class="CSPFileIcon"><img alt="" src="/_layouts/15/images/pdf16.gif"></td><td class="CSPFileName"><a href="https://www.laukiz.eus/eu-ES/INFO/Argitalpenak/laukiz_aldizkaria
				</div>
			</div>
			</div>
		
			<div id="FormZone">
				<div id="ProcedureListZone_auto" class="AspNet-WebPartZone-Vertical">

				</div>
			
			</div>
			<div id="SearchZone">
				<div id="SearchZone_auto" class="AspNet-WebPartZone-Vertical">

					</div>
				
			</div>
			<div id="MessageZone">
				<div id="MessageZone_auto" class="AspNet-WebPartZone-Vertical">

						</div>
					
			</div>
			<div id="RegulationsZone">
				<div id="RegulationsZone_auto" class="AspNet-WebPartZone-Vertical">

							</div>
						
			</div>
		</div>
		<!--end .CenterZone-->
		<div class="RightZone box col-md-12 col-xl-3 col-lg-4">
			<div id="AlertZone">
				<div id="RightAlertZone_auto" class="AspNet-WebPartZone-Vertical">

									<div>
										<div class="ms-WPHeader">
											<h3 class="ms-standardheader ms-WPTitle">
												Eutsi! Aldizkaria
											</h3>
										</div><div class="ms-WPBody">
											<script type="text/javascript" language="javascript">
      var slwp;
      if (slwp == null) slwp = new Array();
      slwp['ctl00_ctl41_g_8434a4d5_6242_4940_85f8_29dbd950f37c'] = "WebForm_DoPostBackWithOptions\u0028new WebForm_PostBackOptions\u0028\u0022ctl00$ctl41$g_8434a4d5_6242_4940_85f8_29dbd950f37c\u0022, \u0022SLWPToken\u0022, false, \u0022\u0022, \u0022\u0022, true, true\u0029\u0029";
    </script><table id="slwp_ctl00_ctl41_g_8434a4d5_6242_4940_85f8_29dbd950f37c" cellspacing="0" cellpadding="0" class="slm-layout-main"><tbody><tr><td valign="top"><div class="slm-layout-main"><ul><li><div class="item link-item linkitem"><a href="/eu-ES/INFO/Argitalpenak/Orriak/EutsiAldizkaria_2010.aspx">Ikusi guztiak</a></div></li></ul></div></td></tr></tbody></table>
										</div>
									</div>
									</div>
								
			</div>
			<div id="ProcedureRightZone_auto" class="AspNet-WebPartZone-Vertical">

										</div>
									
			<div id="RightSearchZone">
				<div id="RightSearchZone_auto" class="AspNet-WebPartZone-Vertical">

											</div>
										
			</div>
			<div id="OtherInfoZone">
				<div id="RightOtherInfoZone_auto" class="AspNet-WebPartZone-Vertical">

												</div>
											
			</div>
			<div id="AdZone">
				<div id="RightAdZone_auto" class="AspNet-WebPartZone-Vertical">

													</div>
												
			</div>
		</div>
		<!--end .RightZone-->
		<div class="clearer"></div>
	</div>
	<!--end #MainContent-->
	<div class="clearer"></div>
</div>
<!--ends .layout-wrapper-->
<div style="display:none" id="hidZone"><div id="wpz_auto" class="AspNet-WebPartZone-Vertical">

														</div>
													</div>
                           </span>
                        </div>
                     </div>


"""
